# %% [markdown]
# <a href="https://colab.research.google.com/github/KeeganFernandesWork/attendance-register/blob/main/yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !git clone https://github.com/rahilkhann/rahils_first.git #cloning rahils repository

# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git # Cloning all the yolov5 repo on the sever
# !cd ./yolov5
# !pip install -r ./yolov5/requirements.txt #install dependencies
# !pip install wandb
# !pip install roboflow

# %%
# from roboflow import Roboflow
# rf = Roboflow(model_format="yolov5", notebook="ultralytics")

# %%
import os
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Tg1au7XQgVVLE2eR3r1i")
project = rf.workspace().project("attendence-cwxzg")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/attendence-1 in yolov5pytorch:: 100%|██████████| 620/620 [00:00<00:00, 1170.92it/s]

# %%
import yaml
config = {'path': '/',
         'train': '/content/datasets/attendence-1/train',
          'test' : '/content/datasets/attendence-1/test',
         'val': '/content/datasets/attendence-1/valid',
         'nc': 2,
         'names': ['keegan','rahil']}
 
with open("data.yaml", "w") as file:
   yaml.dump(config, file, default_flow_style=False)

# %%
SIZE = 640
BATCH_SIZE = 3
EPOCHS = 20
MODEL = "yolov5x" 
WORKERS = 1
PROJECT = "Attendance"
RUN_NAME = f"{MODEL}_size{SIZE}_epochs{EPOCHS}_batch{BATCH_SIZE}_small"

# %%
# !wandb disabled # Since we can't display the results on kaggle we will disable W&B
# !python ./yolov5/train.py --img {SIZE}\
#                --batch {BATCH_SIZE}\
#                --epochs {EPOCHS}\
#                --data ./data.yaml\
#                --weights {MODEL}.pt\
#                --workers {WORKERS}\
#                --project {PROJECT}\
#                --name {RUN_NAME}\
#                --device 0
#                --exist-ok
# Out:
# W&B disabled.

# %%
# !python ./yolov5/train.py --img 416 --batch 16 --epochs 150 --device 0 --data ./data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=./data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --source /content/datasets/attendence-1/train/images/WIN_20230127_19_20_49_Pro-2-_jpg.rf.bf7eadfd04d1f37ac5349ad4bf97f939.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp4/weights/best.pt'], source=/content/datasets/attendence-1/train/images/WIN_20230127_19_20_49_Pro-2-_jpg.rf.bf7eadfd04d1f37ac5349ad4bf97f939.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/datasets/attendence-1/train/images/WIN_20230127_19_20_49_Pro-2-_jpg.rf.bf7eadfd04d1f37ac5349ad4bf97f939.jpg: 640x640 1 keegan, 12.3ms
# ...
