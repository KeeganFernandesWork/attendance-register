# %%
# %%capture
# !pip install ultralytics

# %%
# %%capture
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
import os
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# %%capture
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Tg1au7XQgVVLE2eR3r1i")
project = rf.workspace("test-vuyuu").project("attendence-cwxzg")
dataset = project.version(2).download("yolov8")

# %%
dataset

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=64 imgsz=640 plots=False
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 150MB/s]
# Ultralytics YOLOv8.0.29 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
import cv2
import numpy as np

# %%
model = YOLO("/content/best (2).pt")

# %%
path = "/content/datasets/attendence-2/train/images/WIN_20230125_19_03_55_Pro_jpg.rf.0b69ce62f97116c8833feb9aba6266e8.jpg"
image = cv2.imread(path)
im = image
results = model.predict(source=im)
#[x-axis , y-axis , height, width , probability , class]

# %%
results.probs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-fe1b6b825f8c> in <module>
# ----> 1 results.probs
#
# AttributeError: 'list' object has no attribute 'probs'

# %%
model.export()

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=path
# Out:
# Ultralytics YOLOv8.0.29 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.8/dist-packages/ultralytics/yolo/cfg/__init__.py", line 266, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/model.py", line 147, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/predictor.py", line 119, in predict_cli
#     for _ in gen:  # running CLI inference without accumulating any outputs (do not modify)
#   File "/usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/predictor.py", line 142, in stream_inference
# ...
